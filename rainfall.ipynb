# %% [markdown]
# # USING MULTIPLE LINEAR REGRESSION FOR RAINFALL PREDICTION TO AID IN IMPROVING ACCURACY OF WEATHER FORECAST

# %% [markdown]
# # Importing our libraries
# 1. Pandas
# 2. Sklearn
# 3. Math

# %%
import pandas
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt

# %% [markdown]
# # Dataset before cleaning

# %%
df = pandas.read_csv("weather.csv")
df
# Out:
#      MinTemp  MaxTemp  avgTemp  Evaporation  Sunshine  WindSpeed9am  \
# 0        8.0     24.3      NaN          3.4       6.3           6.0
# 1       14.0     26.9      NaN          4.4       9.7           4.0
# 2       13.7     23.4      NaN          5.8       3.3           6.0
# 3       13.3     15.5      NaN          7.2       9.1          30.0
# 4        7.6     16.1      NaN          5.6      10.6          20.0
# ..       ...      ...      ...          ...       ...           ...
# 361      9.0     30.7      NaN          7.6      12.1           7.0
# 362      7.1     28.4      NaN         11.6      12.7           2.0
# 363     12.5     19.9      NaN          8.4       5.3          11.0
# 364     12.5     26.9      NaN          5.0       7.1           6.0
# 365     12.3     30.2      NaN          6.0      12.6          31.0
#
#      WindSpeed3pm  WindSpeedAvg  Humidity9am  Humidity3pm  HumidityAvg  \
# 0              20           NaN           68           29          NaN
# ...

# %% [markdown]
# # Dataset after cleaning

# %%
df = pandas.read_csv("file.csv")
df
# Out:
#      Evaporation  Sunshine  WindSpeed  Humidity  Pressure  Temperature  \
# 0            3.4       6.3       13.0      48.5   1017.35       17.575
# 1            4.4       9.7       10.5      58.0   1010.40       21.025
# 2            5.8       3.3        6.0      75.5   1008.35       18.175
# 3            7.2       9.1       27.0      59.0   1006.25       14.100
# 4            5.6      10.6       24.0      58.5   1018.40       12.550
# ..           ...       ...        ...       ...       ...          ...
# 360          6.8       3.5        9.5      32.5   1015.90       19.050
# 361          7.6      12.1       28.5      26.5   1013.45       22.525
# 362         11.6      12.7       10.5      33.5   1018.45       20.225
# 363          8.4       5.3       10.0      55.0   1023.40       16.300
# 364          5.0       7.1       17.0      54.0   1018.60       20.275
#
#      Rainfall
# 0         0.0
# 1         3.6
# 2         3.6
# 3        39.8
# 4         2.8
# ..        ...
# ...

# %% [markdown]
# # Defining our data attributes. Independent variables
# They include:
# 1. Evaporation
# 2. Sunshine
# 3. WindSpeed
# 4. Humidity
# 5. Pressure
# 6. Temperature

# %%
x = df[['Evaporation', 'Sunshine', 'WindSpeed', 'Humidity', 'Pressure', 'Temperature']]
x
# Out:
#      Evaporation  Sunshine  WindSpeed  Humidity  Pressure  Temperature
# 0            3.4       6.3       13.0      48.5   1017.35       17.575
# 1            4.4       9.7       10.5      58.0   1010.40       21.025
# 2            5.8       3.3        6.0      75.5   1008.35       18.175
# 3            7.2       9.1       27.0      59.0   1006.25       14.100
# 4            5.6      10.6       24.0      58.5   1018.40       12.550
# ..           ...       ...        ...       ...       ...          ...
# 360          6.8       3.5        9.5      32.5   1015.90       19.050
# 361          7.6      12.1       28.5      26.5   1013.45       22.525
# 362         11.6      12.7       10.5      33.5   1018.45       20.225
# 363          8.4       5.3       10.0      55.0   1023.40       16.300
# 364          5.0       7.1       17.0      54.0   1018.60       20.275
#
# [365 rows x 6 columns]

# %% [markdown]
# # Defining our dependent variable
# 1. Rainfall.
# This is the attribute that our model will try and predict from the data

# %%
y = df['Rainfall']
y
# Out:
# 0       0.0
# 1       3.6
# 2       3.6
# 3      39.8
# 4       2.8
#        ...
# 360     0.0
# 361     0.0
# 362     0.0
# 363     0.0
# 364     0.0
# Name: Rainfall, Length: 365, dtype: float64

# %% [markdown]
# # Splitting our data into training and testing sets.
# The data is split into:
# 1. 80% for training
# 2. 20% for testing

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# # Initializing our Linear regresion model
# We initialize our model by creating an instance of the class LinearRegression

# %%
regr = linear_model.LinearRegression()

# %% [markdown]
# # Training the model
# This is done by calling the fit() method which is given the data inputs, x_train and y_train as arguments

# %%
regr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Testing the model
# the model is tested by calling the predict() method which is given data input, x_test as arguments

# %%
y_prediction = regr.predict(x_test)

# %% [markdown]
# # Printing the model perfomance metrics
#  We print the mean squared error(MSE) which is the Mean or Average of the square of the difference between actual and estimated values. it is squared since some eroor values are negative. we then find the square root of MSE to find the mean error.

# %%
mse = mean_squared_error(y_test, y_prediction)
error = sqrt(mse)
print(f"mean squared error is {mse}")
print(f"error value is {error}")
# Out:
# mean squared error is 14.48595191311904
# error value is 3.8060415017599376
